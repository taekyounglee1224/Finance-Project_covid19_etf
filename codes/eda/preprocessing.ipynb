# %% [markdown]
# ## 실제 사용 가능한 시계열성 외생변수 추출

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#GenAge = pd.read_csv('Covid19GenAgeCaseInf.csv')
InfState = pd.read_csv('Covid19InfState.csv')
#NatInfState = pd.read_csv('Covid19NatInfState.csv', encoding = 'utf-8')
#SidoInfState = pd.read_csv('Covid19SidoInfState.csv')

# %%
#GenAge.tail(30)

# %%
InfState.head(50)
# Out:
#      seq   stateDt stateTime   decideCnt  clearCnt  examCnt  deathCnt  \
# 0   1231  20230420     00:00  31039863.0       NaN      NaN   34401.0
# 1   1230  20230419     00:00  31025769.0       NaN      NaN   34392.0
# 2   1229  20230418     00:00  31009261.0       NaN      NaN   34386.0
# 3   1228  20230417     00:00  30994088.0       NaN      NaN   34376.0
# 4   1226  20230415     00:00  30978954.0       NaN      NaN   34368.0
# 5   1225  20230414     00:00  30967692.0       NaN      NaN   34366.0
# 6   1224  20230413     00:00  30956026.0       NaN      NaN   34361.0
# 7   1223  20230412     00:00  30944430.0       NaN      NaN   34356.0
# 8   1222  20230411     00:00  30930504.0       NaN      NaN   34342.0
# 9   1221  20230410     00:00  30918060.0       NaN      NaN   34332.0
# 10  1219  20230408     00:00  30904502.0       NaN      NaN   34322.0
# 11  1218  20230407     00:00  30894559.0       NaN      NaN   34318.0
# ...

# %%
#NatInfState.head(50)

# %%
#SidoInfState.head(50)

# %%
df1 = InfState[['stateDt',	'decideCnt',	'clearCnt',	'examCnt',	'deathCnt', 'careCnt',	'resutlNegCnt',	'accExamCnt',	'accExamCompCnt',	'accDefRate']]
df1.head()
# Out:
#     stateDt   decideCnt  clearCnt  examCnt  deathCnt  careCnt  resutlNegCnt  \
# 0  20230420  31039863.0       NaN      NaN   34401.0      NaN           NaN
# 1  20230419  31025769.0       NaN      NaN   34392.0      NaN           NaN
# 2  20230418  31009261.0       NaN      NaN   34386.0      NaN           NaN
# 3  20230417  30994088.0       NaN      NaN   34376.0      NaN           NaN
# 4  20230415  30978954.0       NaN      NaN   34368.0      NaN           NaN
#
#    accExamCnt  accExamCompCnt  accDefRate
# 0         NaN             NaN         NaN
# 1         NaN             NaN         NaN
# 2         NaN             NaN         NaN
# 3         NaN             NaN         NaN
# 4         NaN             NaN         NaN

# %%
InfState.tail(20)
# Out:
#       seq   stateDt stateTime  decideCnt  clearCnt  examCnt  deathCnt  \
# 1128   20  20200211     16:00       28.0       4.0    762.0       NaN
# 1129   19  20200211     09:00       28.0       4.0    865.0       NaN
# 1130   18  20200210     16:00       27.0       3.0    531.0       NaN
# 1131   17  20200210     09:00       27.0       3.0    809.0       NaN
# 1132   16  20200209     16:00       27.0       3.0    888.0       NaN
# 1133   15  20200209     09:00       25.0       3.0    960.0       NaN
# 1134   14  20200208     16:00       24.0       2.0    939.0       NaN
# 1135   13  20200208     16:00       24.0       2.0    939.0       NaN
# 1136   12  20200208     16:00       24.0       2.0    939.0       NaN
# 1137   11  20200208     16:00       24.0       2.0    939.0       NaN
# 1138   10  20200208     09:00       24.0       2.0    620.0       NaN
# 1139    9  20200207     16:00       24.0       2.0    327.0       NaN
# ...

# %%
InfState.isnull().sum()
# Out:
# seq                  0
# stateDt              0
# stateTime            0
# decideCnt            2
# clearCnt           458
# examCnt            457
# deathCnt            37
# careCnt            515
# resutlNegCnt       515
# accExamCnt         457
# accExamCompCnt     515
# accDefRate         515
# createDt             0
# updateDt          1063
# dtype: int64

# %%
InfState.drop(['createDt', 'updateDt', 'seq'], axis = 1, inplace = True)

# %%
InfState
# Out:
#        stateDt stateTime   decideCnt  clearCnt  examCnt  deathCnt  careCnt  \
# 0     20230420     00:00  31039863.0       NaN      NaN   34401.0      NaN
# 1     20230419     00:00  31025769.0       NaN      NaN   34392.0      NaN
# 2     20230418     00:00  31009261.0       NaN      NaN   34386.0      NaN
# 3     20230417     00:00  30994088.0       NaN      NaN   34376.0      NaN
# 4     20230415     00:00  30978954.0       NaN      NaN   34368.0      NaN
# ...        ...       ...         ...       ...      ...       ...      ...
# 1143  20200205     09:00        18.0       NaN    129.0       NaN      NaN
# 1144  20200204     00:00         NaN       NaN      NaN       NaN      NaN
# 1145  20200203     09:00        15.0       NaN      NaN       NaN      NaN
# 1146  20200202     09:00         2.0       2.0      2.0       2.0      NaN
# 1147  20200101     18:00         NaN       1.0      1.0       NaN      NaN
#
#       resutlNegCnt  accExamCnt  accExamCompCnt  accDefRate
# ...

# %%
InfState = InfState.groupby('stateDt').first().reset_index()

# %%
InfState = InfState.sort_values('stateDt', ascending = False).reset_index(drop = True)

# %%
InfState
# Out:
#        stateDt stateTime   decideCnt  clearCnt  examCnt  deathCnt  careCnt  \
# 0     20230420     00:00  31039863.0       NaN      NaN   34401.0      NaN
# 1     20230419     00:00  31025769.0       NaN      NaN   34392.0      NaN
# 2     20230418     00:00  31009261.0       NaN      NaN   34386.0      NaN
# 3     20230417     00:00  30994088.0       NaN      NaN   34376.0      NaN
# 4     20230415     00:00  30978954.0       NaN      NaN   34368.0      NaN
# ...        ...       ...         ...       ...      ...       ...      ...
# 1106  20200205     19:00        19.0       1.0     40.0       NaN      NaN
# 1107  20200204     00:00         NaN       NaN      NaN       NaN      NaN
# 1108  20200203     09:00        15.0       NaN      NaN       NaN      NaN
# 1109  20200202     09:00         2.0       2.0      2.0       2.0      NaN
# 1110  20200101     18:00         NaN       1.0      1.0       NaN      NaN
#
#       resutlNegCnt  accExamCnt  accExamCompCnt  accDefRate
# ...

# %%
InfState.isnull().sum()
# Out:
# stateDt             0
# stateTime           0
# decideCnt           2
# clearCnt          457
# examCnt           457
# deathCnt           18
# careCnt           485
# resutlNegCnt      485
# accExamCnt        427
# accExamCompCnt    485
# accDefRate        485
# dtype: int64

# %%
InfState.drop('stateTime', axis = 1, inplace = True)

# %%
InfState
# Out:
#        stateDt   decideCnt  clearCnt  examCnt  deathCnt  careCnt  \
# 0     20230420  31039863.0       NaN      NaN   34401.0      NaN
# 1     20230419  31025769.0       NaN      NaN   34392.0      NaN
# 2     20230418  31009261.0       NaN      NaN   34386.0      NaN
# 3     20230417  30994088.0       NaN      NaN   34376.0      NaN
# 4     20230415  30978954.0       NaN      NaN   34368.0      NaN
# ...        ...         ...       ...      ...       ...      ...
# 1106  20200205        19.0       1.0     40.0       NaN      NaN
# 1107  20200204         NaN       NaN      NaN       NaN      NaN
# 1108  20200203        15.0       NaN      NaN       NaN      NaN
# 1109  20200202         2.0       2.0      2.0       2.0      NaN
# 1110  20200101         NaN       1.0      1.0       NaN      NaN
#
#       resutlNegCnt  accExamCnt  accExamCompCnt  accDefRate
# 0              NaN         NaN             NaN         NaN
# 1              NaN         NaN             NaN         NaN
# ...
