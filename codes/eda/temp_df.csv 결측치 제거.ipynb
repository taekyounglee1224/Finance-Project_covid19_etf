# %%
import pandas as pd

# %%
# csv파일을 데이터프레임으로 바꾸기
temp_df = pd.read_csv('/temp_df.csv')

# %%
#null값을 0으로 채우기, 인덱스 0~18까지 값을 0으로 채우기
temp_df.loc[0:20, 'deathCnt'] = 0

# %%
# 데이터 프레임 확인
temp_df.head()
# Out:
#    Unnamed: 0   stateDt  decideCnt  deathCnt
# 0        1110  20200101        2.0       0.0
# 1        1109  20200202        2.0       0.0
# 2        1108  20200203       15.0       0.0
# 3        1107  20200204       19.0       0.0
# 4        1106  20200205       19.0       0.0

# %%
# 데이터프레임을 csv파일로 바꾸어 저장
temp_df.to_csv('temp_df_final.csv')
